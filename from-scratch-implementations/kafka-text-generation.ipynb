# %%
import numpy as np
from random import randint

# %%
kafka = open('kafka.txt').read()
uniqueChars = list(set(kafka))

charToIndex = { char:index for index, char in enumerate(uniqueChars) } 
indexToChar = { index:char for index, char in enumerate(uniqueChars) } 

encodingDimens = len(uniqueChars)
def encode(character):
    vector = np.zeros((encodingDimens, 1))
    vector[charToIndex[character]] = 1
    return vector
def decode(vector):
    charIndex = [index for index in range(len(vector)) if vector[index] == 1][0]
    return indexToChar[charIndex]

# %%
def tanh(x):
    return np.tanh(x)
def softmax(x):
    return np.exp(x) / np.sum(np.exp(x))

# %%
hiddenUnits = 100
batchLength = 25
learningRate = 1e-1
mu = 0
sigma = 1
y  = np.array([0, 1, 1, 0])
Wxh = np.random.normal(mu, sigma, (hiddenUnits, encodingDimens)) * 0.01
Whh = np.random.normal(mu, sigma, (hiddenUnits, hiddenUnits)) * 0.01
Why = np.random.normal(mu, sigma, (encodingDimens, hiddenUnits)) * 0.01

bh = np.zeros((hiddenUnits, 1))
by = np.zeros((encodingDimens, 1))

def predict(X, previousBatchHiddenState = np.zeros((hiddenUnits, 1))):
    batchLength = len(X)
    
    a0, a1, a2 = {}, {}, {}
    z1, z2 = {}, {}
    
    y = {}
    
    previousHiddenState = {}
    previousHiddenState[0] = previousBatchHiddenState

    for time in range(batchLength):
        a0[time] = X[time]
        z1[time] = np.dot(Wxh, a0[time]) + np.dot(Whh, previousHiddenState[time]) + bh
        a1[time] = tanh(z1[time])
    
        z2[time] = np.dot(Why, a1[time]) + by
        a2[time] = softmax(z2[time])
        
        previousHiddenState[time+1] = a1[time];
        
    return a2[0];

def loss(X, y, previousBatchHiddenState = np.zeros((hiddenUnits, 1))):
    batchLength = len(X)
    crossEntropy = 0
    loss, gradients = 0, {}
    
    a0, a1, a2 = {}, {}, {}
    z1, z2 = {}, {}
    
    previousHiddenState = {}
    previousHiddenState[-1] = np.copy(previousBatchHiddenState)

    for time in range(batchLength):
        a0[time] = X[time]
        z1[time] = np.dot(Wxh, a0[time]) + np.dot(Whh, previousHiddenState[time-1]) + bh
        a1[time] = tanh(z1[time])
    
        z2[time] = np.dot(Why, a1[time]) + by
        a2[time] = softmax(z2[time])
        previousHiddenState[time] = a1[time];
        crossEntropy += -np.log(a2[time][y[time],0])
    
    a1[-1] = np.zeros_like(a1[0]); 
    gradWxh, gradWhh, gradWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    gradbh, gradby = np.zeros_like(bh), np.zeros_like(by)
    deltaStatePrevious = np.zeros_like(previousHiddenState[0])
    
    delta3, delta2 = {}, {}
    for time in reversed(range(batchLength)):
        
        softmaxPrime = np.copy(a2[time])
        softmaxPrime[y[time]] -= 1
        a1_tanhPrime = (1 - a1[time] * a1[time])
        
        delta3 = softmaxPrime
        delta2 = np.dot(Why.T, delta3) + deltaStatePrevious  
        deltaStatePrevious = np.dot(Whh.T, delta2 * a1_tanhPrime) 
            
        gradWhy += np.dot(delta3, a1[time].T)
        gradWhh += np.dot(delta2 * a1_tanhPrime, a1[time-1].T)
        gradWxh += np.dot(delta2 * a1_tanhPrime, a0[time].T) 
        
        gradby  += delta3  
        gradbh  += delta2 * a1_tanhPrime 
        
    for grad in [gradWxh, gradWhh, gradWhy, gradbh, gradby]:
        np.clip(grad, -5, 5, out=grad)

    return crossEntropy, (gradWhy, gradWhh, gradWxh, gradbh, gradby), previousHiddenState[batchLength - 1]

# %%
def getBatch(position):
    X = [ch for ch in kafka[position:position+batchLength]]
    for i,ch in enumerate(X):
        X[i] = encode(ch)
    
    y = [charToIndex[ch] for ch in kafka[position+1:position+batchLength+1]]
    
    return X,y

def getSampleForGeneration(length, previousState = np.zeros((hiddenUnits, 1))):
    seedIndex = charToIndex['a']
    X = np.zeros((encodingDimens, 1))
    X[seedIndex] = 1
    generatedSequence = list()
    
    a0, a1, a2 = {}, {}, {}
    z1, z2 = {}, {}
    
    for time in range(length):
        a0[time] = X
        z1[time] = np.dot(Wxh, a0[time]) + np.dot(Whh, previousState) + bh
        a1[time] = tanh(z1[time])
    
        z2[time] = np.dot(Why, a1[time]) + by
        a2[time] = softmax(z2[time])
        
        charIx = np.random.choice(range(encodingDimens), p=a2[time].ravel())
        
        generatedSequence.append(charIx)
        X = np.zeros((encodingDimens, 1))
        X[charIx] = 1
        
        previousState = a1[time]
        
    text = ''.join(indexToChar[ix] for ix in generatedSequence)
    text = '----\n %s \n----' % (text, )
    return text

# %%
iteration, position = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby         = np.zeros_like(bh), np.zeros_like(by)                                                                                                               
smoothLoss       = -np.log(1.0 / encodingDimens)* batchLength

previousBatchHiddenState = np.zeros_like(bh)

while (iteration <= 1000 * 100):   
    if (position + batchLength + 1 >= len(kafka) or iteration == 0):
        previousBatchHiddenState = np.zeros_like(bh)
        position = 0
        
    X, y = getBatch(position)    
    cost, grads, previousBatchHiddenState = loss(X, y, previousBatchHiddenState)
    gradWhy, gradWhh, gradWxh, gradbh, gradby = grads
    smoothLoss = smoothLoss * 0.999 + cost * 0.001

    if(iteration % 1000 == 0):
        previousBatchHiddenState = np.zeros_like(bh)
        print(getSampleForGeneration(200,previousBatchHiddenState ))
        print(smoothLoss)
                                                                                                                                            
    for param, dparam, mem in zip([Why, Whh, Wxh, bh, by],
                                [gradWhy, gradWhh, gradWxh, gradbh, gradby],
                                [mWhy, mWhh, mWxh, mbh, mby]):
        mem += dparam * dparam
        param += -learningRate * dparam / np.sqrt(mem + 1e-8)                                                                                                                

        
    position += batchLength                                                                                                                                                        
    iteration += 1
# Out:
# ----
#  çvIzxxDCçuzf1x!cPWDYBJ:;nF/T)0$m;bf8LH"(gXre HHY3vffnI20aG-Tzk62dcuKgF;b,YT'YsQVXTn0vGGrlHT.dcYVz)LbXiRh6$awe"oJgcDh
# P8rVOMh!($s84j4yWJzKuLHsoYO-9ç4XPq.@ghw24@$)d1 FF((oPEim5tuT.(3C-%RnW(e*NnVeP5BYd@D
# ----
# 109.5506735396861
# ----
#  d linve
#  to t he witoh waig's" doz antts we e" ding of sart eT hut thuget hme thels woref fLs tofir ha hen  wler yh nhre tiras, four tinr r teugo art hrase afre.nat ninegt ?n hotaf torsgomis rimt aagg
# ----
# 85.09605380501263
# ----
#  lth theeye fobeoxengthe baataslen belri I iutttoat an fouldrre ler antary sovimed moft couf jmke theedime acton nilas Greusis tar ind the. An fuc monind woregh Sudied ckuwave eis uusinugsomoul h tht p
# ----
# 68.15565378233076
# ----
#  n çe cis roond gast clenthe's'ls has lomckessarcouscinld whimno""H ht whieny ime lainet wasped tor s is wave withal tome -nd anigis H ounnllyath chen wandelinge wee; killle fas loradiaba il sem il- as
# ----
# 59.813337415589984
# ----
#  ncaped hissor hom worvey on. Gr, n-e ond thtid che eve sisar choy hly anin, sicere phenzy an saly toe in ho hey Gref thes ray awipf her, eo ead beto pould cubemint mehit dotimegaray at hir ance of to
# ----
# 55.66284626334191
# ----
#   cn, douccis Sowd.
#
# Svith to tule bato Gre toree Pece eftin
# oin.
#
# d angr
# an louttis weonghe dored atlroti termpegom worercmighe wakks thrusery as feesingimiv, ofn ared warloorgobe wor thing teringis a
# ----
# 57.70118920627514
# ----
#   se core her ow no in inkh thor ho den; "orbenly weay ouvilath
# ectthiver. wqow- th uhe he tol yor in or.
# The wagr ore and the phes tad uf bu not thais yolling and eve and ofe her mel chined wand. Yer
# ----
# 58.42602328375915
# ----
#  t whe tha ftof thes we all fastuse ci he his laadl wengratf, wad nalt toagis wif mareathiet of of tor th inclyot to for lat autlisable fert bo to clat fisile beay hithhe to on torweroomont wis the mep
# ----
# 54.19555299318287
# ----
#  nin vid elis. Grendter
#  of if issteer andndes butten's is path sing of thap. ull sfrdengissit ay turto gore toud he the hitay he anmed nighe totled had wo co mourepy to dter fnowen fletes of sse to fi
# ----
# 51.16849221742881
# ----
#  r hereer'cice happer, aventy to)ned of ims was pl aseladpt the thougs her would dioned bliind alsitis llaterste of anlt bhen eghes pichobf abifuchte lasiseld in it winullen in mloute had sfarkenay of
# ----
# 49.737235738481225
# ----
#  d the her the faathed unt pawisher the sfeath hid out wole flyean fnather the was chot of and his anste ar tuke thed. EN wom wis being aund vhes been then noom in "
# xad the deot no a kiwh fwer fecs on
# ----
# 49.20592448441658
# ----
#  le pra4ing, that pout rige eme fule on sidatect lioaime thaur sin
# ely of of ine ine
# becefcsuPntited
# UAUld plliepraseccipseit Guste
# Fomedineite
# Pracconty
# uve Arerout fone to Abece wort with meck rexenb
# ----
# 55.26173972397916
# ----
#  nd the ald the yuthortis thime tit could otho's sonkich gorn hi thes a clent so wor's sso te wroms the he co doort one raking he he y-re. fre;: not of tood rown. alld. Sardsnit was he roon awe ever, h
# ----
# 52.36568979867173
# ----
#  t iamed youst, sacraibt abmceve hatrint Gregole nos fit dibust but had bemed sughe would and the theed brang, inzed are hos sverail ald go she puthor the fnom ut durelned. Awtany sot Gregarcdid wo mom
# ----
# 49.2039089873348
# ----
#  d eve bitull but wat, the wertiom, thad but had and he jughing umsabe th to ding lathiapveapk ary was the chway andy whers slo thed his hasreast, him a he vey tustor Whe ar goid bve peragasy she the r
# ----
# 47.4103473962829
# ----
#  relse to her lonk w!uved she miff lout; enplasing not apat ever atter.
# Thly in and lipdey as her ked in memplest inserd it he morelcad thel Gregor mathtere tamy, donthedy to momeite he fund and wistrr
# ----
# 46.817111524912804
# ----
#  thirin, il it worcieftsive Gregormed Prlainn, brevevinger oc nent tustasing of whishaingas Prid cenosmise. The co oover yis becthen mowent Greitul ecpult an ifingpemed out the to itre. Sam twak of fri
# ----
# 49.54960721809022
# ----
#  sar waychar.w.
#  And thing wort hor sear but wind, diser with that monts hay bepten the his an the out ut walllowing to hid has puining the herturn he dore he wis ho den pumen in. Ale he torut tod a do
# ----
# 51.37822513473185
# ----
#  yo htor the moimeplile his thly to flousted. In tisk, thotis even ragfeinn the reap, sich. Nas far mongo wave you ofor yor ade foom pot thabl in faraid o fer fuld his pfook and of thay fbeelaeropy to
# ----
# 48.67530996395491
# ----
#  ren to the erenake allinbasfont exfe sims'd fraing his ase veL, and lo and fore or the fere spividlenter he blound. That ar the hiis the cound be the nepent of for the coul. Vviet hay wir now, forly f
# ----
# 46.514760880841344
# ----
#  ble the che ble she fore. The init lely the his sisegcan and o s lotce enther/t, amenanect the labne an in for not ans only stary hathaud formers, and siwt nith. It reovniops, naine souke thes fat atl
# ----
# 45.77750149152623
# ----
#  de mowrtiby dovered hem. Bary." Eowh reout had wherk""thent, and cnothing thes testore thay teed hes surveden the dos ereapavent midaves dove wans huld an thet yole the domemen nated, sothen wangt pyi
# ----
# 45.65325563225419
# ----
#  nct Fed mothtause a sovisteng otted
#  wassuong of the sud onste prenta whylying undoors naid ce ifyidaictiens enocess in ompsoro ag of ot Proje
# FoTh Plation bnen
# ther. F onld coll ace aulmoreng, in fro
# ----
# 50.754183175515976
# ----
#  de and indon paroarfan hoo hit let tement propreg- ikseats spebiges undinberg trseet omat at Gregormer noubrrgot a lele to cousped oghliagay could whikgough: Four haw could on ot would not weraw rok m
# ----
# 48.81050131673182
# ----
#  nd fath werby stelied somculling list, as thatregmt mome ugh ous sely vittors om to to genting donce got dose hims byou'llnich enth yot farver lenger, ho remont Guthe jugnsm sain hand there a with dro
# ----
# 46.46315681658069
# ----
#  lly tiof thoull buthermed took, sto to ard wrold wereapses fere yius not secting us lathir, called lith in obray the cisters ar ile to the foor a lear becte the wholes's he that on have, turmed of tha
# ----
# 44.90499858636955
# ----
#  nd'r not efvery breftherer by wave wiplt comely as tenwir. Gregor pathon the forent-ge'l wave of hesher fothirbt as conented and even all roolls aset his woum iven to qulely, to tarked and eand sistun
# ----
# 44.61144313365736
# ----
#  ded )fU; he wiflly,.
#
# Ho botrement. The
#
# 5ise cor't! wo- wormorg-tchen the placengor o withougrwim, to prink fould sliemed mowene thour thin coupelf? She Priveavursase Gregork
# (IU GBegor thay ant raki
# ----
# 47.04470073057842
# ----
#  d us sfoffieer of to waths epel is reen by the moteecty ylith lind forebolive tus himly wowled.n wuCl the was sam on earl.
# ATthous in vittrrickt. If tanbould ber and and perener ixpseincegh (ompunse s
# ----
# 48.93842736049446
# ----
#  nst gumin calls wad ho"k and "It he hor beregrs; allalesing lith to his serot becara, Thay the camp that rewor far the che was foul; samousentert's loder to. I aly gusting head en mac to histed stary
# ----
# 46.583957408415
# ----
#  t us of the be bury, her helt on weres ward of as tiff eare braild a foos if has ever.  The good in ulent grent him gigus gom enonk of more at as usen shech buind. "Fou nrom fit, in arcthing hecard wa
# ----
# 44.70724764750043
# ----
#  d in at would and jed the side was would buskest to his nus elackion the wook in tate, to moulls as dearry, her fathe was weat ontey alk be that he fors, by ture do bine overytand, dectiem to her; ere
# ----
# 44.21911752752259
# ----
#  nd hit cumplat canved a dialedly - Greffith ally reon reopxon's had onlms, would and wx*" the soon his omenomeen moot, the was evening lergon ommead mefor site it as the to sistin sele and coull cook
# ----
# 44.18423520928147
# ----
#  rs exppocing fork
# onosseds of triveares wifat condot e$tergolf ot
#
# peact, repetcklytiontite Inforemem., anpovent Gregor/aivedent a quicuted impous vouct: Proj,
# petterbect go sheresenting, of trimadect
# ----
# 48.85999211127691
# ----
#  nt bate, terce. Prowain stofr. Bout be his phe lowrw,, forist what ase. "Gregor's ay pagat ins roon him unfudite in motile a deary Ipeamlyibesceg thie migrmaintly for encisencomed tarmonir them way in
# ----
# 47.30329860238486
# ----
#  rse the to gerwory it thation; ting and hams sher; in toud his fath to the mat over whatredely front leds was sterser, saltely fead at the mid whad had back the
# Sasp preaple wrel sown beferin
# sist hit
# ----
# 44.88990865584499
# ----
#  d there he he hay seast helped whilast his foon to his side re be ofing tetens leint. Gregor's had had at het hestes agaied Gretly and that would him forros at whemed that, himing, and neaund, whis; w
# ----
# 43.48496185674425
# ----
#  mele do to onl her shiesmearle o, hors", the raithoughers, the juse the rooms; olly at and went show, sto herly thly? The petned oning time thendut sticcwion ar it stele fort, seed hadret werea, had o
# ----
# 43.3899307948491
# ----
#  scay thes'rling
# comay that and urgeared the deching Gregorgiage.  I more. Anly the for accearsened beto
# w.Se enpedive awaing ary priart andes ficicenburg-ifution eupcaniling this sister, bech the claa
# ----
# 45.40812857463678
# ----
#  nd rocesce to his far's he buts hork/bogianzling himsliech a
# died 1 Linkad his werion fet a mopners is while everonged om trid bore, the have wam she tmoutely insive he latcem the as omrearrgiong, ont
# ----
# 47.55055589097322
# ----
#  nd.
# ST A. Him his, himraint, furing; reectroo, her speret he lay sted that her that in the becat he mospent trameres. Shat steardy:, as thas alrearb Iw thay to and and ophe couftid cerichil of mowt, a
# ----
# 45.47922889973018
# ----
#  ps a reade throcking durnzening witleter hild fro his dorminiand her reght suneps  at od hall w. L
#  the sad that suty dick anrets wrying weald ve; soo courde with hes thable beenings but his fot nothr
# ----
# 43.76927439611844
# ----
#  nd taree, as it on clonte the dort sacking eavered alat to even rave fain looked ledpt foon ither thew the noald that him ssatiend to the would shemeds about aple format dees the vould asling had boti
# ----
# 43.2369476532736
# ----
#  rgrye gat the paroed Mn. "Che benothing youghtle ut's monken empveatho Gregor theed, snos evey they would the mistae.
#  He reance oftin to he wathly the othed, and Gregor, a gead ir thraid the dlong ti
# ----
# 43.180707359921655
# ----
#  rrby wowrsed an use it compercowady at ourd. Anethingerpiens equestly forloon or Projet
#
# 1.F.1.'s
#
# ffontaind utpare vow
#  uquert
#
# LI Fonkion the raghime "Denectict Plyoy
# doupent were cant poprdect
#
# Wf
# ----
# 47.81983364389318
# ----
#  nsed whaless themee thtabratled to have to cours h an, asame it even a longer nour, and the Projeet gom the foon hadsentes", alle almace othur. Whthe, thetroutherpegrhalf any by could you totang aghat
# ----
# 46.35663728979965
# ----
#  shintten, stle food a moor suster in, the clofe an the so and if is had door foker the haver and cayang wiuld? The not al, thoughting lich daid farmed be pelun expliss the wight. "He the becaust of it
# ----
# 44.131989059850135
# ----
#  mepfiss, it in the dude aTroo, mome down wefesissary. He whad was butterb, cost had nother, the dan't did and for his hardly, that cont, he was goup.
#
# Gregor that would of the dale peiveny as an at to
# ----
# 42.764521164988714
# ----
#  n! He ef a so wles him thouse to him as intick and gor his time had not shy back, sourner M) Gregor'F insad bore, openitt, wither disi thay back boght eamedly her. The to not stavergor thoy the puslet
# ----
# 42.681056533894626
# ----
#  msenoreameger. Meneft on the cerakenbectignt gead this nearto the pnok as to the doors, siaterw, fas late
# her the eatinfy any shath, Gregor; od Gregor's. Mr and mookts, inmeriteme of sippeirsed in w2a
# ----
# 44.57156712705207
# ----
#  nde dores" amamicarg him wescey if hrow thlide to thole on dtot thact as Anloth, "Nout Grest it to cnitserw, decary to and with thould in ad exing. Whout he was beco, hims his fore as of parsisserm ha
# ----
# 46.62513933512516
# ----
#  d not had was softing hethougrarg
# tremeng: G thupered time he chay that appet to had s. "", oflick las fat thes he has that holling fall hill. In him work "chied and wour. Anouf howher, the bept quide
# ----
# 44.655647619090594
# ----
#  r, fivend the been noud rey usgen to deas, Gregor'n imply asling in any him, her more see he was rathen ipleting, hive othuntr prented ly he parialy was redly, in hild her, whey and Grtendeder tim. Su
# ----
# 42.94358753915988
# ----
#  lly as she itence he would splingerst his mavnyor's hiss inyister uneed was not and from. Her and woull the faun oft him of arain slowing alrand Gren her of hither, semplister had sid nverly, he nif p
# ----
# 42.64446394760523
# ----
#  nse, get was soyen to youc  ghe sanders from had wherrying Gregor of in it out oupingen him genthe! AnNy the chale brom have the jed sfewo bad not his beaned sase nopl, I. In, just to was seve his don
# ----
# 42.576958852629225
# ----
#  rst.
# 00-y, was iss this
# ightmone had to frome.
#
# 1.F the begm ancta m in jutm on in or the socrust boche fatmed the conis, oven mulm, foupsith they Sif butcradoucring aidubore they
# MLE.2Yo$6 by wor pro
# ----
# 46.86581351463351
# ----
#  ic to sard of he was fand get his asl or and mide to ththen so out of hisnriblcly Greger of his requed it was lyat pathly." hescees whiud, s'p mo, by geived ingust mess thon up the coucard to dleained
# ----
# 45.58558991401773
# ----
#  rsond and some then that main or all him noke and werive tume was .ly so haf herret he spfertack and, cout lioms the wampinozed daddacked and the aled, his playo tay froken to do chiegher for and the
# ----
# 43.5726210117945
# ----
#  nsite hrom had the aibrenbeving earnt the door and door or and thet he would father no father werder "oth to to copln, would wifmet us a wooking que not's moopsing to homk sematted was thomen seane, a
# ----
# 42.189155033663454
# ----
#  d to gad to pup cis mtotile abray onening to her fathe's day to clywey it his nister pareflleefuly in there were sadyed that wither atherwwight nating her ger cuve after fore instrile vent the catturl
# ----
# 42.03940420831537
# ----
#  ct wibpr.
#
# Buced the maps would fore agcistrow him was gover coul, olly, in anvingats of the copssarr do theed work. Aboled or withine nott; age work of ons oth thiSt. If opappriving mowher the could
# ----
# 43.82096727647083
# ----
#  ndiden this attand sor. And to (grat mone. Ardle his retiritely do coud he a  Ie of they not him.
#  buld forter had bechistlly thonging that hee" 9poskessiblly hell sivery dastury. Withidided befoops,
# ----
# 45.853129478641385
# ----
#  ns asollaimathe weald; him they sere and nistoly this the father as for nyieel, fipprenet Gregor have and fortele hirns pout the fortion rears, backed Gregor by no quy on the father fabre. The beriou
# ----
# 44.12271030120721
# ----
#  r hims byed the other erhabp and an hast hey he relastaevousesture sue cared he5 onlird her be the sored or quescul they not he who go, mon't sor fourditilusted morigu. IL thaulpy hayss speed a llasce
# ----
# 42.51761107684405
# ----
#  de uth work; hasing ups in dot mlyerts on he weple." now the cherarase thee's, in the learling wrot winted ase and but mime jacking berany he sailen bugh not equire it in  hr nost his tome with to fro
# ----
# 42.16192518580964
# ----
#  ry. Andw and trow it!"
#
# Ifley byrribld."
# Them strath pains, forte enot preaspprootrige haze reving, Gregor sust Gregor. So dascook to ally the mextrend to from eved stibo soon bust they Gotely dooked
# ----
# 42.13982741355277
# ----
#  r thicurmedingined to becopit in ladidien
# roject westning sarmmerpercone a mument forsanly you woup yuindy the voy to cournement bectront ger"5Liod she strow out like, Mr totargingeded make for agrobu
# ----
# 46.001127176924456
# ----
#  dnich. Ald afelent caich "other foren acowow to yous, her coprane, ally lakerand wat s. I's seraw deeps colls cerencel. As souss in the ling Molreg it tanbed strid notemegthirgauculse's thel morempith
# ----
# 44.88823324468523
# ----
#  s; agreally indor, leally couch, tele ald treanizecing the to a hersed lingork in the hally down as eviut nowne sigher, shes hersely roow wor preard, al, she soos to nristacture this tenter, to in sea
# ----
# 42.94160382264122
# ----
#  tt ast, the the like out fak it moprong. Susen't solilly Rind whthe himmot alreamed but leray, any was hims intow, to to his potrech to caring; - to geave becate to to ald ar thone siman? "hee that af
# ----
# 41.77873464697259
# ----
#  vereg" L.
# ittem the sak the'spewly and a king his fasill but in his samept reart it; the chacedn that the cise would at rlessed wianredy. Theh, he'rd cloth Prive sue seom clerl on, was could evense t
# ----
# 41.616564736425254
# ----
#  rs. Some.
#
# roke out if sawzyed enkion.
#  Withligistenbed oply in wither iven with.
#
# Stoly Le entengway, neem cistroting thew they
# reying", war siduly dipled a Pwome, as jot e8parerigom would in wore to
# ----
# 43.40347753640921
# ----
#  michunticems witene to gichoru workse 500 che of hind not Lernible auld fron out of vially pritted tramidd he whout butm to to a leriand not sicule sickle ulfeat ex he nely Lite reras us whe in the pa
# ----
# 45.30800324885419
# ----
#  nde. Samsintong there muck bely, the collew but at, morel. Nout was for at the bel the reingnt the to the could uk.
# Mf any had he menkbong him forting the prige reent sise that a proke od thing himle?
# ----
# 43.63234197228482
# ----
#  rseadly his she to sainttlytion his moit jut not on cant do shere gees thoughAd hrempaly usound now earmbone and Wain "Sal in the sest could did hold for as and for it to gar". - farment surtougs feft
# ----
# 42.036939902574055
# ----
#  s a mid eupindmargot thay nomess though somed, have and get his modecher, aboitand Greger and ally with had asent ated leentustaro tray frove hims plage -. At tod the faf her, ted his histing that of
# ----
# 41.81250531029217
# ----
#  d. He held sut thet then to setaline them in us to ap they her sidasely straitante
# s olle. Gregor's his harking whele her now? "stempy ald shad hapis sastly all and ronk eumpone thest them
# when leaspr
# ----
# 41.6430848051484
# ----
#  nsick sucplet on for wook, Pctot tide compllaictigg orn abuten that it thairdu got, a to, ey time in the linger, all the
# chicfcts bbemonging by thaut ardey forray the aryed, payine, and or olld the si
# ----
# 45.186223375115254
# ----
#  shiongly or on Leand, I holde, his spick wroze. Bo
#
#
# Grent s as is throusidly ally had agm.
#  It not beck bets ofthish wholp fork pain nealing the chisg this gen't thick lefpeast trime would thon ham b
# ----
# 44.396180251276974
# ----
#  s wh the ratyly cspight of de of chu expectillow  yound poulvef eIt ulwearrailf the lolaritibed harghe siytly draveinf calf he had cmopsees and the brayer the ary sime eveet looventy the liessiute som
# ----
# 42.59197679069662
# ----
#  spett be and a notest though hed fould to "the wo-ly had hels the ro-t, had belpspite holl sad hhar arrey time wente hit hit not that even! woul thay eund though cotho spather for whick out fust to ro
# ----
# 41.37062348389271
# ----
#  s Gregor sinth sietten to steking on the outhor" it of aftolly, really to kever.
#
# In and and as siwto weon pliack ut her"wenot of muct,:, ut thtien eaw mained alk redeatlares the no her sher becady or
# ----
# 41.21684000304473
# ----
#  rdifat a dayd frome were had allly to lith it was as byed aft moment and to the FoUs.
#
# Grest, out ite goterg
# Grfut oms teme forkion, and thay in, anly:/-way, car work in atw aite whe picing yout come
# ----
# 42.85265189497886
# ----
#  r lecu mecousy, or the mwoteng arrained to sicule were the moster of to dey. Howare apting would in a toon having requemten so may, dotroulmer to dift went, of the
# wore luft antiog Gregor as the ond,
# ----
# 44.919195953860196
# ----
#  letrigred to gein clobride dest hal takl. And frow for up parn and was as he waar from the mars bet mattlo open wrher, the lest ho her opele.
#
# On as him thought was ataprly dounbed if which was masl a
# ----
# 43.4156948863018
# ----
#  s herary as he pain him the door mlorgers eveantionst trablong the remelt thow efreded litm in he him, no mast and bay ho courdely the would to want to his fand had and incemened at pifu breanty,, som
# ----
# 41.774116411998286
# ----
#  n she, the, the fish but he waspet speroster baininute bwon Greger.
#
# 1.E.8(bontsion comes thes a his enache before, lack hears, chienourd held meffurted but atains youtertry fereunge what his rood his
# ----
# 41.53380566852762
# ----
#  s afied noul Gregor's sinsout - him do fulmly onfully the camdover undoll stoss stalle infathiburs. Theefiarwing they plyigingliny grouly the vioust oft nast the has asplee, rurd; to sokenbed tideinda
# ----
# 41.48881994312603
# ----
#  s fie, the moked werents imm micitiond paghary of Preeforg Fout paining. Somell ats of the antoo find wead becaft Project
# 5JU for thiagamections and in conds anating, by cere down.
#
# Tferstated was com
# ----
# 45.13917707617729
# ----
#  d padion really and light with her bitites but have, sarich of the gent - I dele to to Gregor's door "Do -e aping to geaded whong batt gentlect a rould had not for to liok receeds, "wayn? It lith seed
# ----
# 44.17917815148887
# ----
#  ssiten alleanss, expongwhe's desol ind in Gregor slask a copand lutcery. He was was sicpentuld the strist wore each eat ind of 9$ noich the lot have of him, was sper-od stmefad dedared mpeand to he ha
# ----
# 42.29537866067005
# ----
#  d openbniculied bearies dryet way enosfret wable eppatill or to even watleth, would for ut Gut iomesw, ie, in eurd on him anyiker doneeded sle restester, Gregor's til her comatryace to mying hip hay s
# ----
# 41.207351501639025
# ----
#  rd toull, his had lay ap list coveat and was. Gregor, him. H the was pame they alminged spair would winns the bee epering, the to you nen come had obrayingdime shing hemsher there for of dides. In. Th
# ----
# 41.018317496522215
# ----
#  rd, lomen the lode iny. Samsackt,
# wnirg copnered out works seed norink the rees a that he wary
# whein she lock a wetting on the choying hip al wead, and a chingting doprote to the for it a  though, a k
# ----
# 42.56221858220974
# ----
#  r to que fore the fho coved cout
# it prist he not by
# diok yound that he daked, lad extal. Aillg wanger at cover head sop, sasy lroke dich notranet that and dest rnems gacked buts, but the whe halried a
# ----
# 44.46056744191857
# ----
#  rg uawe - ex the fret reealr wam ingitter be him wetelf side taking his hladearriving had them again a sook the frosidion bice bearne) the fionters agay thes's for that unsted to mochuralters, ard of
# ----
# 43.097464612837406
# ----
#  r, Mime cour sjeeck Ino than what; lice seary fro besnce nonter, bonnich him stulf ex; usibare agreaterm, gat reouth re to about came coul to ver ploe wat ond ast, Stared him pathly wherms as is hir f
# ----
# 41.46746916750585
# ----
#  nter that theich. "Than himsted dust but to it his clikels dottemed evee has been and in but noid hin begang Gregor. "whined the preath Gregor had chist in the famile, the cheresthoughir room it ot
#  f
# ----
# 41.2444375414515
# ----
#  nsilenorbed, Gregor's to had forsted real had. It with to he was sonelt, but micate hen a slewgit, legth; hor - lelt.
# Gregor's quite it her and hut he had had to the his ane wear they periar had sice
# ----
# 41.04794838414586
# ----
#  r bite
# provinite acounty to abe atquidiled all Projecthain at you misfor! Dh wo kong Mr jut.
#
# *Th Sef a moppressaisetaon
# any tonecien of agaise you cimestion if contionation seppice: of an of ortels b
# ----
# 44.26396308142859
# ----
#  rsing. Hapt you plogaribly be his te wow - on neat me es this he pay father it bed ingurtion's pear stany thine. The the would atway, have, wonger? I's mather usted mad sustledide "what has degs shato
# ----
# 43.61866140380239
